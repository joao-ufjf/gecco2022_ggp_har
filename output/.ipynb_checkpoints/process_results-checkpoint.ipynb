# %%
import os
import pandas as pd

directory = os.getcwd() + "/output/activity-6"
dfs = []

for root, subdirectories, files in os.walk(directory):
#     for subdirectory in subdirectories:
#         print(os.path.join(root, subdirectory))
#     for file in files:
#         print(os.path.join(root, file))
    for file in files:
        if file.endswith("res.csv"):
#             print(os.path.join(root, file))
            df = pd.read_csv(os.path.join(root, file), sep = ";")
#             print(len(df))
            dfs.append(df)
            
# dfs

# %%
results = pd.concat(dfs)
results = results[results.seed.isin([1, 2, 3])]
results.columns = ['seed', 'training', 'validation', 'test', 'model']
results.describe()
# Out:
#             seed    training  validation        test
# count  120.00000  120.000000  120.000000  120.000000
# mean     2.00000    0.365635    0.392237    0.242336
# std      0.81992    0.096428    0.113545    0.083319
# min      1.00000    0.245040    0.175595    0.071429
# 25%      1.00000    0.299045    0.312500    0.185268
# 50%      2.00000    0.327009    0.379464    0.250000
# 75%      3.00000    0.414745    0.461310    0.305803
# max      3.00000    0.695685    0.714286    0.482143

# %%
results[results.test == results.test.min()]
# Out:
#    seed  training  validation      test  \
# 1     3  0.491319    0.514881  0.071429
# 0     3  0.272817    0.428571  0.071429
# 1     3  0.361359    0.389881  0.071429
#
#                                                model
# 1  physical emotional mental ECG_hrv_min 0 < if-e...
# 0  physical mental ECG_RR_window_prctile25 ECG_hr...
# 1  emotional mental ECG_HR_min_div_mad ECG_hrv_tr...

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from __future__ import division
import random
from sympy import *

IF_ELSE = set(['if-else'])
BINARY_OPERATORS = set(['+', '-', '*', '/', '^', '<', '<=', '==', '>=', '>', '!=', 'and', 'or'])
UNARY_OPERATORS = set(['log', 'sqrt', 'exp', 'sin'])

### POSTFIX ===> INFIX ###
'''
1) When see an operand, push
2) When see an operator, pop out two numbers, connect them into a substring and push back to the stack
3) the top of the stack is the final infix expression.
'''
def postfix_to_infix(formula):
    stack = []
    for ch in formula.split():
        if ch in BINARY_OPERATORS:
            if ch == "^":
                ch = "**"
            b = stack.pop()
            a = stack.pop()
            expr = "(" + a + ch + b + ")"
            stack.append(expr)
        elif ch in UNARY_OPERATORS:
            a = stack.pop()
            expr = ch + "(" + a + ")"
            stack.append(expr)
        elif ch in IF_ELSE:
            c = stack.pop()
            b = stack.pop()
            a = stack.pop()
            expr = "if(" + c + "){\n" + a + "\n}else{\n" + b + "\n}"
            stack.append(expr)
        else:
            stack.append(ch)

    return stack[-1]

def postfix_to_infix_pyton(formula, constants):
    stack = []
    c_counter = 0
    for ch in formula.split():
        if ch in BINARY_OPERATORS:
            if ch == "^":
                ch = "**"
            b = stack.pop()
            a = stack.pop()
            expr = "(" + a + ch + b + ")"
            stack.append(expr)
        elif ch in UNARY_OPERATORS:
            a = stack.pop()
            expr = ch + "(" + a + ")"
            stack.append(expr)
        elif ch in IF_ELSE:
            c = stack.pop()
            b = stack.pop()
            a = stack.pop()
            expr = "if(" + c + "):\n" + a + "\nelse:\n" + b + "\n"
            stack.append(expr)
        elif ch in ["_c_"]:            
            stack.append(str(constants[c_counter]))
            c_counter = c_counter + 1
        else:
            stack.append(ch)

    return stack[-1]

# if __name__ == '__main__':
#     infix = postfix_to_infix_pyton("cost income - cost return / + cost income - return income / + + cost return cost + - cost return * cost / + * income income return / ^ return return return * income cost * * * * /")
#     print("PG output: " + infix)
#     # print("Simplify: " + str(simplify(infix)))

# %%
infix = []

for i, model in results.iterrows():
    infix.append(postfix_to_infix_pyton(model.model, []))

# %%
results['infix'] = infix

# %%
# results.to_csv("PG/output/activity-000/results.csv", index = None)

# %%
print(list(results[results.test.min() == results.test].model))
# Out:
# ['physical emotional mental ECG_hrv_min 0 < if-else HAND_EDA_Functionals_power_Filt2max 0.5 ECG_RR_window_median * >= if-else mental neutral ECG_amplitude_RR_min -0.75 < if-else neutral ARM_EDA_Functionals_power_Originalprctile25 0.75 >= -0.25 ECG_HF_TF != or if-else IT_HF_skewness IT_HF_prctile75 >= IT_LF_min HAND_EDA_Filt1_harmmean > -1 -0.5 > or and if-else ', 'physical mental ECG_RR_window_prctile25 ECG_hrv_mean < if-else neutral emotional IT_PSD_skewness -0.5 IT_BRV_prctile75 * < if-else IT_PSD_skewness -0.75 >= HAND_EDA_Functionals_power_Originalprctile25 HAND_EDA_Functionals_power_Fil12baseline > and ECG_hrv_prctile25 IT_BRV_mad >= or if-else ', 'emotional mental ECG_HR_min_div_mad ECG_hrv_trimmean25 >= if-else neutral IT_BRV_mad IT_LF_MF_HF <= IT_RF_min IT_BRV_harmmean <= and if-else neutral mental ECG_p_LF_prctile25 -0.25 >= if-else mental physical IT_LF_prctile75 -0.5 < if-else IT_LF_skewness ECG_RR_window_prctile25 == -0.75 IT_LF_MF_HF >= and if-else -0.75 IT_LF_max * ECG_original_geomean(abs) - ECG_hrv_prctile25 > if-else ']

# %%
results
# Out:
#     seed  training  validation      test  \
# 0      3  0.300099    0.452381  0.366071
# 1      1  0.457093    0.455357  0.267857
# 2      2  0.318204    0.416667  0.250000
# 0      2  0.306548    0.398810  0.187500
# 1      3  0.279514    0.270833  0.160714
# ..   ...       ...         ...       ...
# 1      3  0.304067    0.264881  0.178571
# 2      1  0.339534    0.437500  0.125000
# 0      1  0.585813    0.636905  0.321429
# 1      3  0.278026    0.315476  0.232143
# 2      2  0.391865    0.526786  0.410714
#
#                                                 model  \
# 0   physical mental 0 ECG_p_MF_mean != if-else neu...
# 1   emotional physical IT_RF_min ECG_hrv_mean > if...
# 2   mental emotional -0.5 IT_MF_baseline < if-else...
# 0   neutral mental ARM_EDA_Filt2_baseline IT_HF_ba...
# 1   neutral physical HAND_EDA_cross_neg -0.5 <= if...
# ..                                                ...
# 1   emotional mental ECG_hrv_median -0.5 < if-else...
# 2   emotional physical ARM_EDA_processed_median EC...
# 0   physical neutral mental ECG_hrv_median -0.25 >...
# 1   neutral mental IT_MF_HF -0.75 < -1 IT_BRV_medi...
# 2   emotional physical ECG_original_geomean(abs) 0...
#
#                                                 infix
# 0   if(((ECG_RR_window_geomean(abs)<=IT_HF_LF)and(...
# 1   if((((ECG_p_total_LF_mad>IT_BRV_std)and(-0.25<...
# 2   if(((IT_RF_baseline>0)and((IT_HF_LF/0.75)>-1))...
# 0   if(((1-1)>=((-1*IT_HF_LF)/1))):\nif((IT_HF_prc...
# 1   if((IT_Original_mean>=(-0.25*-0.25))):\nif((AR...
# ..                                                ...
# 1   if((IT_LF_MF_HF>=0.25)):\nif(((-0.25<=ECG_RR_w...
# 2   if((((-0.25>=IT_HF_TF)and(ECG_hrv_min!=IT_Orig...
# 0   if(((-1<0.5)or(IT_LF_MF_HF>(HAND_EDA_processed...
# 1   if((((ECG_amplitude_RR_mad+IT_BRV_baseline)+0)...
# 2   if((IT_LF_MF_HF>IT_BRV_std)):\nif((IT_LF_MF_HF...
#
# [120 rows x 6 columns]
